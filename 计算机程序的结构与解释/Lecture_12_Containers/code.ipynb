# %%
# Slice
odds = [1,2,3,4,5]
list(range(1,3))
[odds[x] for x in range(1,3)]
odds[1:3]
odds[1:]
odds[:1]
odds[:]
odds[::2]
# Out:
# [1, 3, 5]

# %%
# Sum
# 在使用sum对List进行加和的时候要指定一下初始的类型
sum([2,3,4],5)
# sum(['1','2','3'],[]) # 会报错
sum([[2,3],[4]],[])
# Out:
# [2, 3, 4]

# %%
# Max
max(range(4))
max(range(4),key=lambda x : (x-1)**2)
# Out:
# 3

# %%
# All
all(range(4))
# Out:
# False

# %%
# String
City = 'Berkeley'
len(City)
City[4]
# Out:
# 'e'

# %%
# 在列表当中，我们只能一个元素一个元素地去找，但在字符串当中，我们可以找连续的字母
'here' in "where's waldo"
234 in [1,2,3,4,5]
[2,3,4] in [1,2,3,4,5]
# Out:
# False

# %%
# Dictionaires

{x*x: x for x in range(1,6) if x > 2}

def index(keys, values, match):
    """Return a dictionary from keys k to a list of values v for which
    match(k,v) is a true value
    >>> index([7,9,11], range(30,50), lambda k, v: v % k == 0)
    {7:{35,42,49}, 9:[36,45], 11:[33,44]}
    """
    return {k : [v for v in values if match(k,v)] for k in keys}
index([7,9,11], range(30,50), lambda k, v: v % k == 0)
# Out:
# {7: [35, 42, 49], 9: [36, 45], 11: [33, 44]}
